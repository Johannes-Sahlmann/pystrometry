# %% [markdown]
# # Plot the astrometric signatures of known exoplanet host stars
#
# In this notebook we query two exoplanet catalogs and estimate the expected amplitude (semi-major axis) of the host star's Keplerian motion caused by the orbiting planet.
#
# Dependencies:
#     astropy, pandas, astroquery, pystrometry

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# !conda list pandas
# Out:
# # packages in environment at /opt/conda/envs/astrom:
# #
# # Name                    Version                   Build  Channel
# pandas                    1.4.2            py38h47df419_1    conda-forge

# %%
# 1/0

# %%
import glob
import os
import pprint 

import astropy.constants as constants
from astropy.table import Table, vstack
import astropy.units as u
from astroquery.nasa_exoplanet_archive import NasaExoplanetArchive
from astroquery.exoplanet_orbit_database import ExoplanetOrbitDatabase
from IPython.display import display
import matplotlib as mp
import matplotlib.pylab as pl
import numpy as np
import pandas as pd

from pystrometry.pystrometry import semimajor_axis_barycentre_angular
# Out:
# /tmp/ipykernel_444/548016499.py:8: DeprecationWarning: the ``nasa_exoplanet_archive`` module has been moved to astroquery.ipac.nexsci.nasa_exoplanet_archive, please update your imports.
#   from astroquery.nasa_exoplanet_archive import NasaExoplanetArchive

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
# Out:
# universal_helpers not available
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:33: UserWarning: registration of accessor <class 'pystrometry.utils.du437_tools.NssDataFrame'> under name 'nss' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class NssDataFrame:
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:566: UserWarning: registration of accessor <class 'pystrometry.utils.du437_tools.NssMonteCarloDataFrame'> under name 'nssmc' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class NssMonteCarloDataFrame(NssDataFrame):

# %%
LOCAL_PATH = os.path.dirname(os.getcwd())
TEMPORARY_DIR = os.path.join(LOCAL_PATH, 'temp')
if os.path.isdir(TEMPORARY_DIR) is False:
    os.makedirs(TEMPORARY_DIR)
print(LOCAL_PATH)
# Out:
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry

# %%
pp = pprint.PrettyPrinter(indent=4)     
# %matplotlib inline
mp.rcParams['figure.figsize'] = (18, 9)
mp.rcParams['font.size'] = 20
mp.rcParams['ytick.direction'] = 'in'
mp.rcParams['xtick.direction'] = 'in'

# %%
save_plot = True

# %% [markdown]
# ### Some useful functions
#
# https://exoplanetarchive.ipac.caltech.edu/docs/program_interfaces.html

# %%
def get_exoplanets(selected_table_name, overwrite=False):
    
    local_data_file_name = {'eod': 'exoplanet_orbit_database_table.ecsv',
                           'nasa': 'nasa_exoplanet_archive_table.ecsv'}

    eod_file = os.path.join(TEMPORARY_DIR, local_data_file_name[selected_table_name])

    if not os.path.isfile(eod_file) or overwrite:
        if selected_table_name == 'eod':
            table = ExoplanetOrbitDatabase.get_table()
        elif selected_table_name == 'nasa':
            # https://exoplanetarchive.ipac.caltech.edu/docs/program_interfaces.html
            table = NasaExoplanetArchive.query_criteria(table="exoplanets", select="*", cache=True)
            #         table = NasaExoplanetArchive.query_criteria(table="cumulative", select="*", cache=True)
            #         table_kepler = NasaExoplanetArchive.query_criteria(table="cumulative", select="*", cache=True)

        table.write(eod_file, overwrite=True)

    table = Table.read(eod_file)
    return table


parameter_mapping_all = {'eod': {'period': 'PER',
                     'ecc': 'ECC',
                     'm2': 'MASS',
                     'omega': 'OM',
                     'plx': 'PAR',
                     'star_mass': 'MSTAR',
                     'distance_pc': 'DIST'
                     },
                     'nasa':{'period': 'pl_orbper',         # https://exoplanetarchive.ipac.caltech.edu/docs/API_exoplanet_columns.html
                             'm2': 'pl_bmassj',
                             'plx': 'gaia_plx',
                             'star_mass': 'st_mass',
                             'distance_pc': 'st_dist'
                             }}


def set_astrometric_observables(table, selected_table_name):
    """Compute photocentre orbit size and other parameters."""

    parameter_mapping = parameter_mapping_all[selected_table_name]                     

    planet_mass_mj = table[parameter_mapping['m2']]
    parallax_mas = table[parameter_mapping['plx']]
    period_day = table[parameter_mapping['period']]
    star_mass_msun = table[parameter_mapping['star_mass']]

    table['a_phot_mas'] = semimajor_axis_barycentre_angular(star_mass_msun, planet_mass_mj, period_day, parallax_mas)
    table['period_year'] = (table[parameter_mapping['period']].to(u.year))
    table['a_phot_muas'] = table['a_phot_mas']*1000

    table['log10_distance_pc'] = np.log10(table[parameter_mapping['distance_pc']])
    
    return table

def set_a_phot_mas(table, selected_table_name):
    """Compute photocentre orbit size (works on pandas dataframe)."""

    parameter_mapping = parameter_mapping_all[selected_table_name]                     

    planet_mass_mj = table[parameter_mapping['m2']]
    parallax_mas = table[parameter_mapping['plx']]
    period_day = table[parameter_mapping['period']]
    star_mass_msun = table[parameter_mapping['star_mass']]

    table['a_phot_mas'] = semimajor_axis_barycentre_angular(star_mass_msun, planet_mass_mj, period_day, parallax_mas)
    table['a_phot_muas'] = table['a_phot_mas']*1000
    
    return table

# %% [markdown]
# ### Get table from NasaExoplanetArchive

# %%
selected_table_name = 'nasa'  
table = get_exoplanets(selected_table_name) 
table = set_astrometric_observables(table, selected_table_name)
# Out:
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/pystrometry.py:4279: RuntimeWarning: invalid value encountered in true_divide
#   M = (Ggrav * (m2_MJ * MJ_kg)**3.
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/pystrometry.py:4249: RuntimeWarning: divide by zero encountered in true_divide
#   d_pc  = 1. / (plx_mas / 1000.)
# /tmp/ipykernel_444/3769182680.py:53: RuntimeWarning: divide by zero encountered in log10
#   table['log10_distance_pc'] = np.log10(table[parameter_mapping['distance_pc']])

# %%
table.columns
# Out:
# <TableColumns names=('ra','st_raerr','st_rah','st_raherr','ra_str','dec','st_decerr','dec_str','st_glon','st_glonerr','st_glat','st_glaterr','st_elon','st_elonerr','st_elat','st_elaterr','st_posn','st_plx','st_plxerr1','st_plxerr2','st_plxlim','st_plxn','st_dist','st_disterr1','st_disterr2','st_distlim','st_distn','st_pmra','st_pmraerr','st_pmralim','st_pmdec','st_pmdecerr','st_pmdeclim','st_pm','st_pmerr','st_pmlim','st_pmn','st_radv','st_radverr1','st_radverr2','st_radvlim','st_radvn','st_uj','st_ujerr','st_ujlim','st_bj','st_bjerr','st_bjlim','st_vj','st_vjerr','st_vjlim','st_rc','st_rcerr','st_rclim','st_ic','st_icerr','st_iclim','st_j','st_jerr','st_jlim','st_h','st_herr','st_hlim','st_k','st_kerr','st_klim','st_wise1','st_wise1err','st_wise1lim','st_wise2','st_wise2err','st_wise2lim','st_wise3','st_wise3err','st_wise3lim','st_wise4','st_wise4err','st_wise4lim','st_irac1','st_irac1err','st_irac1lim','st_irac2','st_irac2err','st_irac2lim','st_irac3','st_irac3err','st_irac3lim','st_irac4','st_irac4err','st_irac4lim','st_mips1','st_mips1err','st_mips1lim','st_mips2','st_mips2err','st_mips2lim','st_mips3','st_mips3err','st_mips3lim','st_iras1','st_iras1err','st_iras1lim','st_iras2','st_iras2err','st_iras2lim','st_iras3','st_iras3err','st_iras3lim','st_iras4','st_iras4err','st_iras4lim','st_optmag','st_optmagerr','st_optmaglim','st_optband','st_photn','st_umbj','st_umbjerr','st_umbjlim','st_bmvj','st_bmvjerr','st_bmvjlim','st_vjmic','st_vjmicerr','st_vjmiclim','st_vjmrc','st_vjmrcerr','st_vjmrclim','st_jmh2','st_jmh2err','st_jmh2lim','st_hmk2','st_hmk2err','st_hmk2lim','st_jmk2','st_jmk2err','st_jmk2lim','st_bmy','st_bmyerr','st_bmylim','st_m1','st_m1err','st_m1lim','st_c1','st_c1err','st_c1lim','st_colorn','st_spstr','st_ssperr','st_splim','st_spn','st_teff','st_tefferr1','st_tefferr2','st_tefflim','st_teffn','st_logg','st_loggerr1','st_loggerr2','st_logglim','st_loggn','st_metfe','st_metfeerr1','st_metfeerr2','st_metfelim','st_metfen','st_metratio','st_lum','st_lumerr1','st_lumerr2','st_lumlim','st_lumn','st_rad','st_raderr1','st_raderr2','st_radlim','st_radn','st_mass','st_masserr1','st_masserr2','st_masslim','st_massn','st_dens','st_denserr1','st_denserr2','st_denslim','st_densn','st_age','st_ageerr1','st_ageerr2','st_agelim','st_agen','st_vsini','st_vsinierr1','st_vsinierr2','st_vsinilim','st_vsinin','st_acts','st_actserr','st_actslim','st_actsn','st_actr','st_actrerr','st_actrlim','st_actrn','st_actlx','st_actlxerr','st_actlxlim','st_actlxn','st_nts','st_nplc','st_nglc','st_nrvc','st_naxa','st_nimg','st_nspec','hd_name','hip_name','swasp_id','pl_name','pl_hostname','pl_letter','pl_pnum','pl_snum','pl_mnum','pl_status','pl_discmethod','pl_disc','pl_disc_refname','pl_publ_date','pl_facility','pl_telescope','pl_instrument','pl_locale','pl_def_refname','pl_rvflag','pl_imgflag','pl_astflag','pl_tranflag','pl_ttvflag','pl_kepflag','pl_k2flag','pl_nnotes','pl_cbflag','pl_omflag','pl_pelink','pl_edelink','pl_orbper','pl_orbpererr1','pl_orbpererr2','pl_orbperlim','pl_orbpern','pl_orbsmax','pl_orbsmaxerr1','pl_orbsmaxerr2','pl_orbsmaxlim','pl_orbsmaxn','pl_orbincl','pl_orbinclerr1','pl_orbinclerr2','pl_orbincllim','pl_orbincln','pl_orbtper','pl_orbtpererr1','pl_orbtpererr2','pl_orbtperlim','pl_orbtpern','pl_orbeccen','pl_orbeccenerr1','pl_orbeccenerr2','pl_orbeccenlim','pl_orbeccenn','pl_orblper','pl_orblpererr1','pl_orblpererr2','pl_orblperlim','pl_orblpern','pl_rvamp','pl_rvamperr1','pl_rvamperr2','pl_rvamplim','pl_rvampn','pl_conrat','pl_conraterr1','pl_conraterr2','pl_conratlim','pl_conratband','pl_conratn','pl_msinij','pl_msinijerr1','pl_msinijerr2','pl_msinijlim','pl_msinie','pl_msinieerr1','pl_msinieerr2','pl_msinielim','pl_msinin','pl_massj','pl_massjerr1','pl_massjerr2','pl_massjlim','pl_masse','pl_masseerr1','pl_masseerr2','pl_masselim','pl_massn','pl_bmassj','pl_bmassjerr1','pl_bmassjerr2','pl_bmassjlim','pl_bmasse','pl_bmasseerr1','pl_bmasseerr2','pl_bmasselim','pl_bmassn','pl_bmassprov','pl_radj','pl_radjerr1','pl_rad ...

# %% [markdown]
# ### Get table from ExoplanetOrbitDatabase for KOIs

# %%
eod_table = get_exoplanets('eod')  
eod_table = set_astrometric_observables(eod_table, 'eod')

eod_df = eod_table.to_pandas()
eod_df_koi = eod_df[eod_df['EANAME'].str.contains('Kepler').fillna(False)]
# Out:
# /tmp/ipykernel_444/3769182680.py:53: RuntimeWarning: divide by zero encountered in log10
#   table['log10_distance_pc'] = np.log10(table[parameter_mapping['distance_pc']])

# %% [markdown]
# ## Solar system planets  at 10 pc
# http://www.windows2universe.org/our_solar_system/planets_table.html

# %%
solar_system = pd.DataFrame()

solar_system['period_year'] = [0.24 ,0.62, 1, 1.88, 11.86, 29.46, 84.01, 164.8]
solar_system['period_day'] = solar_system['period_year'] * u.year.to(u.day)
solar_system['planet_mass_mj'] = np.array([0.055,0.815, 1, 0.107, 318, 95, 15, 17]) * u.M_earth.to(u.M_jup)
solar_system['distance_pc'] = 10
solar_system['parallax_mas'] = 1e3/solar_system['distance_pc']
solar_system['planet_name'] = ['Me','V','E','Ma','J','S','U','N']
solar_system['star_mass_msun'] = 1

solar_system['a_phot_mas'] = semimajor_axis_barycentre_angular(solar_system['star_mass_msun'], solar_system['planet_mass_mj'], solar_system['period_day'], solar_system['parallax_mas'])
solar_system['a_phot_muas'] = solar_system['a_phot_mas']*1e3

display(solar_system)
# Out:
#    period_year  period_day  planet_mass_mj  distance_pc  parallax_mas  \
# 0         0.24     87.6600        0.000173           10         100.0
# 1         0.62    226.4550        0.002564           10         100.0
# 2         1.00    365.2500        0.003146           10         100.0
# 3         1.88    686.6700        0.000337           10         100.0
# 4        11.86   4331.8650        1.000540           10         100.0
# 5        29.46  10760.2650        0.298903           10         100.0
# 6        84.01  30684.6525        0.047195           10         100.0
# 7       164.80  60193.2000        0.053488           10         100.0
#
#   planet_name  star_mass_msun  a_phot_mas  a_phot_muas
# 0          Me               1    0.000006     0.006380
# 1           V               1    0.000178     0.177980
# 2           E               1    0.000300     0.300345
# 3          Ma               1    0.000049     0.048953
# 4           J               1    0.496395   496.395467
# 5           S               1    0.272114   272.113525
# 6           U               1    0.086414    86.414409
# 7           N               1    0.153471   153.470970

# %% [markdown]
# ## Individual systems (mostly Gaia-HIP accelerations)

# %%
individuals = pd.DataFrame()

individuals['planet_name'] = ['HD 33632 Ab', 'Proxima c', 'HD 113337 c', 'HD 38529 c', 'pi Men b', 'beta Pic b', 'eps indi A b']
individuals['ref'] = ['Currie+20', 'Kervella+20', 'Xuan+20', 'Xuan+20', 'De Rosa+20', 'Brandt+20', 'Feng+19']

individuals['period_year'] = np.array([91* u.year.to(u.day), 1900, 3165, 2135, 2089.11, 8880, 45.2*u.year.to(u.day)])* u.day.to(u.year)
individuals['period_day'] = individuals['period_year'] * u.year.to(u.day)
individuals['planet_mass_mj'] = np.array([46, 12* u.M_earth.to(u.M_jup), 14, 18, 13.01, 9.8, 3.25]) 
individuals['distance_pc'] = [26.56, 1000./768.5, 1000./27.64, 1000./23.611, 1000/ 54.7052, 1000./50.58, 1000./274.8]
individuals['parallax_mas'] = 1e3/individuals['distance_pc']
individuals['star_mass_msun'] = [1.108, 0.122, 1.40, 1.36, 1.094, 1.83, 0.754]

individuals['a_phot_mas'] = semimajor_axis_barycentre_angular(individuals['star_mass_msun'], individuals['planet_mass_mj'], individuals['period_day'], individuals['parallax_mas'])
individuals['a_phot_muas'] = individuals['a_phot_mas']*1e3

# %% [markdown]
# ## HIP-Gaia systems from Li+21: Precise Masses and Orbits for Nine Radial Velocity Exoplanets
# #### https://ui.adsabs.harvard.edu/abs/2021arXiv210910422L

# %%
planet_name = '''HD~29021~b 
HD~81040~b 
HD~87883~b   
HD~98649~b 
HD~106252~b
HD~106515~Ab
HD~106515~B
HD~171238~b 
HD~196067~b  
HD~196068
HD~221420~b'''
planet_name = planet_name.split('\n')
planet_name = [s.replace(' ','').replace('~', ' ') for s in planet_name]

m1_ms = '''0.86
0.97
0.80
0.97
1.05
0.90
0.90
0.92
1.34
1.34
1.30'''.split('\n')

planet_mass_mj = '''4.47
7.24
6.31
9.7
10.0
18.9
904
8.8
12.5
1235
20.6'''.split('\n')

period_year = '''3.737
2.7452
8.23
14.74
4.202
9.927
4630
4.148
9.88
44300
27.7'''.split('\n')

parallax_mas = '''32.385
29.063
54.668
23.721
26.248
29.315
29.391
22.481
25.033
25.038
32.102'''.split('\n')

li21 = pd.DataFrame()
li21['planet_name'] = planet_name
li21['star_mass_msun'] = np.array(m1_ms).astype(float)
li21['planet_mass_mj'] = np.array(planet_mass_mj).astype(float)
li21['parallax_mas'] = np.array(parallax_mas).astype(float)
li21['distance_pc'] = 1000./li21['parallax_mas']
li21['ref'] = 'Li+21'
li21['period_year'] = np.array(period_year).astype(float)
li21['period_day'] = li21['period_year']*u.year.to(u.day)

li21['a_phot_mas'] = semimajor_axis_barycentre_angular(li21['star_mass_msun'], li21['planet_mass_mj'], li21['period_day'], li21['parallax_mas'])
li21['a_phot_muas'] = li21['a_phot_mas']*1e3

li21 = li21[li21['planet_mass_mj']<100]
# display(li21)
individuals = pd.concat((individuals, li21))

# %% [markdown]
# ## One system from Feng+21: Optimized modelling of Gaia-Hipparcos astrometry for the detection of the smallest cold Jupiter and confirmation of seven low-mass companions
# https://ui.adsabs.harvard.edu/abs/2021MNRAS.507.2856F/abstract

# %%
feng21 = pd.DataFrame({'planet_name': 'HD 190360 b', 'ref': 'Feng+21', 'period_year': 7.815, 'planet_mass_mj': 1.8, 'parallax_mas': 62.49, 'star_mass_msun': 1.0}, index=[0])
feng21['period_day'] = feng21['period_year']*u.year.to(u.day)

feng21['a_phot_mas'] = semimajor_axis_barycentre_angular(feng21['star_mass_msun'], feng21['planet_mass_mj'], feng21['period_day'], feng21['parallax_mas'])
feng21['a_phot_muas'] = feng21['a_phot_mas']*1e3
feng21['distance_pc'] = 1000./feng21['parallax_mas']
individuals = pd.concat((individuals, feng21))
individuals.reset_index(inplace=True)

# %%
# individuals.columns

# %%
display(individuals)
# Out:
#     index   planet_name          ref  period_year   period_day  \
# 0       0   HD 33632 Ab    Currie+20    91.000000  33237.75000
# 1       1     Proxima c  Kervella+20     5.201916   1900.00000
# 2       2   HD 113337 c      Xuan+20     8.665298   3165.00000
# 3       3    HD 38529 c      Xuan+20     5.845311   2135.00000
# 4       4      pi Men b   De Rosa+20     5.719671   2089.11000
# 5       5    beta Pic b    Brandt+20    24.312115   8880.00000
# 6       6  eps indi A b      Feng+19    45.200000  16509.30000
# 7       0    HD 29021 b        Li+21     3.737000   1364.93925
# 8       1    HD 81040 b        Li+21     2.745200   1002.68430
# 9       2    HD 87883 b        Li+21     8.230000   3006.00750
# 10      3    HD 98649 b        Li+21    14.740000   5383.78500
# 11      4   HD 106252 b        Li+21     4.202000   1534.78050
# 12      5  HD 106515 Ab        Li+21     9.927000   3625.83675
# 13      7   HD 171238 b        Li+21     4.148000   1515.05700
# 14      8   HD 196067 b        Li+21     9.880000   3608.67000
# 15     10   HD 221420 b        Li+21    27.700000  10117.42500
# 16      0   HD 190360 b      Feng+21     7.815000   2854.42875
#
#     planet_mass_mj  distance_pc  parallax_mas  star_mass_msun  a_phot_mas  \
# 0        46.000000    26.560000     37.650602           1.108   30.438599
# 1         0.037756     1.301236    768.500000           0.122    0.337984
# 2        14.000000    36.179450     27.640000           1.400    1.237368
# 3        18.000000    42.353140     23.611000           1.360    1.063517
# 4        13.010000    18.279798     54.705200           1.094    2.031204
# 5         9.800000    19.770660     50.580000           1.830    2.645187
# 6         3.250000     3.639010    274.800000           0.754   13.022748
# 7         4.470000    30.878493     32.385000           0.860    0.366760
# 8         7.240000    34.408010     29.063000           0.970    0.399980
# 9         6.310000    18.292237     54.668000           0.800    1.549806
# 10        9.700000    42.156739     23.721000           0.970    1.339012
# 11       10.000000    38.098141     26.248000           1.050    0.627770
# 12       18.900000    34.112229     29.315000           0.900    2.586240
# 13        8.800000    44.482007     22.481000           0.920    0.512288
# 14       12.500000    39.947270     25.033000           1.340    1.124875
# 15       20.600000    31.150707     32.102000           1.300    4.803489
# 16        1.800000    16.002560     62.490000           1.000    0.422362
#
#      a_phot_muas
# 0   30438.599047
# 1     337.983829
# 2    1237.368314
# 3    1063.516641
# 4    2031.203704
# 5    2645.186869
# 6   13022.747616
# 7     366.759633
# 8     399.979988
# 9    1549.805893
# 10   1339.012118
# 11    627.769762
# 12   2586.239510
# 13    512.287682
# 14   1124.874894
# 15   4803.488719
# 16    422.362443

# %%
# # eps Eri b   Llop-Sayson+21
# # (Mawet+17 ignores the HST astrometry)
# individual_system = df[df['pl_name'].str.contains('eps Eri b').fillna(False)].copy().reset_index()
# individual_system.loc[0,'pl_bmassj'] = [0.66]
# individual_system['ref'] = 'Llop-Sayson+21'


# individuals = pd.concat([individuals, individual_system[individuals.columns]])
# individuals

# %%
print(individuals[['planet_name', 'ref']].to_csv(index=False, sep=';'))
# Out:
# planet_name;ref
# HD 33632 Ab;Currie+20
# Proxima c;Kervella+20
# HD 113337 c;Xuan+20
# HD 38529 c;Xuan+20
# pi Men b;De Rosa+20
# beta Pic b;Brandt+20
# eps indi A b;Feng+19
# HD 29021 b;Li+21
# HD 81040 b;Li+21
# HD 87883 b;Li+21
# HD 98649 b;Li+21
# HD 106252 b;Li+21
# HD 106515 Ab;Li+21
# HD 171238 b;Li+21
# HD 196067 b;Li+21
# HD 221420 b;Li+21
# HD 190360 b;Feng+21

# %% [markdown]
# ## Systems with fully measured photocentre orbits

# %%
df = table.to_pandas()

# ups And c,d
selected_systems = df[df['hip_name'].str.contains('HIP 7513').fillna(False)].iloc[[1,2]]
selected_systems['pl_bmassj'] = [13.98, 10.25]
selected_systems['ref'] = 'McArthur+10'

#  HD 38529 c
individual_system = df[df['pl_name'].str.contains('HD 38529 c').fillna(False)].copy().reset_index()
individual_system.loc[0, 'pl_bmassj'] = [17.6]
individual_system['ref'] = 'Benedict+10'
selected_systems = pd.concat([selected_systems, individual_system])

#  HD 128311 b
individual_system = df[df['pl_name'].str.contains('HD 128311 b').fillna(False)].copy().reset_index()
individual_system.loc[0, 'pl_bmassj'] = [3.789]
individual_system['ref'] = 'McArthur+14'
selected_systems = pd.concat([selected_systems, individual_system])

#  HD 202206 c
individual_system = df[df['pl_name'].str.contains('HD 202206 c').fillna(False)].copy().reset_index()
individual_system.loc[0, 'ref'] = 'Benedict+17'
selected_systems = pd.concat([selected_systems, individual_system])


#  GJ 676A b
individual_system = df[df['pl_name'].str.contains('GJ 676 A b').fillna(False)].copy().reset_index()
individual_system.loc[0, 'pl_bmassj'] = [6.7]
individual_system['ref'] = 'Sahlmann+16'
selected_systems = pd.concat([selected_systems, individual_system])

selected_systems = set_a_phot_mas(selected_systems, 'nasa')

individual_system = pd.DataFrame()
individual_system['pl_name'] = ['TVLM 513–46546 b']
individual_system['pl_bmassj'] = [0.38]
individual_system['a_phot_mas'] = [0.128]
individual_system['ref'] = ['Curiel+20']
individual_system['period_year'] = [220./u.year.to(u.day)]
individual_system['distance_pc'] = [1000./93.405]

individual_system['a_phot_muas'] = individual_system['a_phot_mas']*1000
individual_system['st_dist'] = individual_system['distance_pc']

selected_systems = pd.concat([selected_systems, individual_system])
selected_systems.reset_index(inplace=True)
display(selected_systems[['pl_name', 'period_year', 'pl_bmassj', 'a_phot_muas', 'ref', 'pl_def_refname']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 10>()
#       8 #  HD 38529 c
#       9 individual_system = df[df['pl_name'].str.contains('HD 38529 c').fillna(False)].copy().reset_index()
# ---> 10 individual_system.loc[0, 'pl_bmassj'] = [17.6]
#      11 individual_system['ref'] = 'Benedict+10'
#      12 selected_systems = pd.concat([selected_systems, individual_system])
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/indexing.py:1754, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1750     pass
#    1752 elif self._is_scalar_access(indexer):
#    1753     # We are setting nested data
# -> 1754     self._setitem_single_column(indexer[1], value, pi)
#    1756 elif len(ilocs) == len(value):
#    1757     # We are setting multiple columns in a single row.
#    1758     for loc, v in zip(ilocs, value):
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/indexing.py:1885, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    1879 else:
#    1880     # set the item, first attempting to operate inplace, then
#    1881     #  falling back to casting if necessary; see
#    1882     #  _whatsnew_130.notable_bug_fixes.setitem_column_try_inplace
#    1884     orig_values = ser._values
# -> 1885     ser._mgr = ser._mgr.setitem((pi,), value)
#    1887     if ser._values is orig_values:
#    1888         # The setitem happened inplace, so the DataFrame's values
#    1889         #  were modified inplace.
#    1890         return
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/internals/managers.py:337, in BaseBlockManager.setitem(self, indexer, value)
#     331 def setitem(self: T, indexer, value) -> T:
#     332     """
#     333     Set values with indexer.
#     334
#     335     For SingleBlockManager, this backs s[indexer] = value
#     336     """
# --> 337     return self.apply("setitem", indexer=indexer, value=value)
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/core/internals/blocks.py:953, in Block.setitem(self, indexer, value)
#     948     pass
#     950 elif is_scalar_indexer(indexer, self.ndim):
#     951     # setting a single element for each dim and with a rhs that could
#     952     #  be e.g. a list; see GH#6043
# --> 953     values[indexer] = value
#     955 else:
#     956     value = setitem_datetimelike_compat(values, len(values[indexer]), value)
#
# ValueError: setting an array element with a sequence.

# %%
print(selected_systems[['pl_name', 'ref']].to_csv(index=False, sep=','))
# Out:
# pl_name,ref
# ups And c,McArthur+10
# ups And d,McArthur+10

# %%
gaia_data_dir = '/Users/jsahlmann/code/github/JohannesSahlmann/gaia-exploration-notebooks/nss/du437/outreach/substellar_systems_C9OUTR-170/C9OUTR-170'
files = glob.glob(os.path.join(gaia_data_dir, '*'))
selected_source_ids = []
dfs = []
for f in files:
    if f.endswith('.txt'):
        header=0
        df1 = pd.read_csv(f, usecols=[0], delimiter='&', header=header, names=['sourceId'], dtype=np.int64)
    else:
        header = None
        df1 = pd.read_csv(f, usecols=[0], delim_whitespace = True, header=header, names=['sourceId'], dtype=np.int64)
    # selected_source_ids.append(df['sourceId'].values)
    print(f"read {len(df1)} rows from {os.path.basename(f)} of which {df1['sourceId'].nunique()} unique")
    dfs.append(df1)
df3 = pd.concat(dfs).reset_index(drop=True)    
# print(len(selected_source_ids))    
df3.info()
df3['sourceId'].nunique()
    # print(df)
df3.drop_duplicates(inplace=True)
print(len(df3))
    
root_data_dir = '/Users/jsahlmann/gaia/cu4/data'    
gaia_data_release = 'dr3int6'
data_dir = os.path.join(root_data_dir, gaia_data_release)
from pystrometry.utils.archives import get_gaiadr_data

gaia_table_name = 'nss_two_body_orbit'
analysis_dataset_name = '{}_all'.format(gaia_table_name)
nss_all = get_gaiadr_data(analysis_dataset_name, data_dir, gaia_data_release=gaia_data_release, gaia_table_name=gaia_table_name, overwrite_query=False)
print('Dataset has {} unique source_ids, i.e. {} duplicate source_ids'.format(len(nss_all['source_id'].unique()), len(nss_all)-len(nss_all['source_id'].unique())))

nss_solution_type = ['OrbitalTargetedSearch', 'OrbitalTargetedSearchValidated', 'Orbital', 'OrbitalAlternative', 'AstroSpectroSB1']
# nss_solution_type = ['OrbitalTargetedSearch', 'OrbitalTargetedSearchValidated', 'Orbital', 'OrbitalAlternative']
nss_all = nss_all[nss_all['nss_solution_type'].isin(nss_solution_type)].copy()

dr3 = nss_all[nss_all['source_id'].isin(df3['sourceId'].values)]
# display(dr3)
# Out:
# read 50 rows from OTS_fig49_DPACP100.dat of which 50 unique
# read 762 rows from Orbital_Kdwarfs_and_earlier_fig49_DPACP100.dat of which 381 unique
# read 2690 rows from Orbital_Mdwarfs_fig49_DPACP100.dat of which 1345 unique
# read 19 rows from Tab11.txt of which 19 unique
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sourceId  3521 non-null   int64
# dtypes: int64(1)
# memory usage: 27.6 KB
# 1776
# Retrieved 443205 rows from dr3int6.nss_two_body_orbit
# Dataset has 437275 unique source_ids, i.e. 5930 duplicate source_ids

# %%
from pystrometry.utils import du437_tools
dr3 = dr3.nss.add_geometric_elements()
# Out:
# universal_helpers not available
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._obj[['p1_a1_mas', 'p1_omega_deg', 'p1_OMEGA_deg', 'p1_incl_deg']] = geometric_parameters.T
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._obj[['p1_a1_mas', 'p1_omega_deg', 'p1_OMEGA_deg', 'p1_incl_deg']] = geometric_parameters.T
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._obj[['p1_a1_mas', 'p1_omega_deg', 'p1_OMEGA_deg', 'p1_incl_deg']] = geometric_parameters.T
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._obj[['p1_a1_mas', 'p1_omega_deg', 'p1_OMEGA_deg', 'p1_incl_deg']] = geometric_parameters.T
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._obj.loc[:, 'p1_period_day'] = self._obj.loc[:, 'period']

# %%
dr3['a_phot_muas'] = dr3['p1_a1_mas'] * 1e3
dr3['period_year'] = dr3['period'] * u.day.to(u.year)
dr3['distance_pc'] = 1000 / dr3['parallax']
# 'a_phot_muas'
# Out:
# /tmp/ipykernel_444/3380783077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr3['a_phot_muas'] = dr3['p1_a1_mas'] * 1e3
# /tmp/ipykernel_444/3380783077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr3['period_year'] = dr3['period'] * u.day.to(u.year)
# /tmp/ipykernel_444/3380783077.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr3['distance_pc'] = 1000 / dr3['parallax']

# %%
np.array(df3.columns)
# Out:
# array(['solution_id', 'source_id', 'nss_solution_type', 'ra', 'ra_error',
#        'dec', 'dec_error', 'parallax', 'parallax_error', 'pmra',
#        'pmra_error', 'pmdec', 'pmdec_error', 'a_thiele_innes',
#        'a_thiele_innes_error', 'b_thiele_innes', 'b_thiele_innes_error',
#        'f_thiele_innes', 'f_thiele_innes_error', 'g_thiele_innes',
#        'g_thiele_innes_error', 'c_thiele_innes', 'c_thiele_innes_error',
#        'h_thiele_innes', 'h_thiele_innes_error', 'period', 'period_error',
#        't_periastron', 't_periastron_error', 'eccentricity',
#        'eccentricity_error', 'center_of_mass_velocity',
#        'center_of_mass_velocity_error', 'semi_amplitude_primary',
#        'semi_amplitude_primary_error', 'semi_amplitude_secondary',
#        'semi_amplitude_secondary_error', 'mass_ratio', 'mass_ratio_error',
#        'fill_factor_primary', 'fill_factor_primary_error',
#        'fill_factor_secondary', 'fill_factor_secondary_error',
#        'inclination', 'inclination_error', 'arg_periastron',
#        'arg_periastron_error', 'temperature_ratio',
#        'temperature_ratio_error', 'temperature_ratio_definition',
#        'astrometric_n_obs_al', 'astrometric_n_good_obs_al',
#        'rv_n_obs_primary', 'rv_n_good_obs_primary', 'rv_n_obs_secondary',
#        'rv_n_good_obs_secondary', 'phot_g_n_obs', 'phot_g_n_good_obs',
#        'bit_index', 'corr_vec', 'obj_func', 'goodness_of_fit',
#        'efficiency', 'significance', 'flags', 'conf_spectro_period',
#        'r_pole_sum', 'r_l1_point_sum', 'r_spher_sum', 'ecl_time_primary',
#        'ecl_time_secondary', 'ecl_dur_primary', 'ecl_dur_secondary',
#        'g_luminosity_ratio', 'input_period_error', 'g_rank',
#        'astrometric_jitter', 'rotation_ratio_primary',
#        'rotation_ratio_secondary', 'teff_primary', 'teff_primary_error',
#        'teff_secondary', 'teff_secondary_error', 'logg_primary',
#        'logg_secondary', 'p1_a1_mas', 'p1_omega_deg', 'p1_OMEGA_deg',
#        'p1_incl_deg', 'p1_period_day', 'a_phot_muas', 'period_year',
#        'distance_pc', 'ra_pseudocolour_corr', 'dec_gaia_source',
#        'phot_bp_n_blended_transits', 'non_single_star', 'has_rvs',
#        'has_xp_sampled', 'parallax_error_gaia_source',
#        'grvs_mag_nb_transits', 'parallax_pseudocolour_corr',
#        'has_xp_continuous', 'phot_rp_mean_flux', 'scan_direction_mean_k4',
#        'scan_direction_mean_k3', 'dec_pmra_corr', 'rv_atm_param_origin',
#        'visibility_periods_used', 'scan_direction_mean_k2',
#        'radial_velocity_error', 'vbroad_error', 'scan_direction_mean_k1',
#        'g_rp', 'rv_template_logg', 'in_andromeda_survey',
#        'ra_gaia_source', 'rv_method_used', 'ref_epoch', 'phot_bp_n_obs',
#        'ra_pmdec_corr', 'mh_gspphot_lower', 'azero_gspphot_upper',
#        'rv_renormalised_gof', 'vbroad', 'phot_rp_n_obs',
#        'parallax_gaia_source', 'ra_pmra_corr', 'matched_transits_removed',
#        'rvs_spec_sig_to_noise', 'astrometric_chi2_al',
#        'ipd_gof_harmonic_amplitude', 'phot_bp_mean_flux_error',
#        'rv_chisq_pvalue', 'astrometric_n_obs_ac', 'dec_pseudocolour_corr',
#        'distance_gspphot', 'bp_rp', 'in_galaxy_candidates',
#        'astrometric_matched_transits', 'phot_bp_rp_excess_factor',
#        'astrometric_n_obs_al_gaia_source', 'classprob_dsc_combmod_galaxy',
#        'pmra_error_gaia_source', 'parallax_pmra_corr',
#        'ipd_gof_harmonic_phase', 'ag_gspphot_lower',
#        'distance_gspphot_upper', 'parallax_pmdec_corr',
#        'phot_rp_mean_flux_error', 'b', 'ruwe', 'has_epoch_photometry',
#        'classprob_dsc_combmod_star', 'phot_rp_mean_mag', 'has_epoch_rv',
#        'l', 'dec_pmdec_corr', 'dec_parallax_corr',
#        'phot_g_n_obs_gaia_source', 'rv_template_teff',
#        'phot_g_mean_flux_error', 'astrometric_gof_al',
#        'classprob_dsc_combmod_quasar', 'ebpminrp_gspphot_upper',
#        'phot_rp_n_contaminated_transits', 'rv_template_fe_h',
#        'pmra_pseudocolour_corr', 'phot_g_mean_flux_over_error',
#        'ag_gspphot_upper', 'source_id_2', 'distance_gspphot_lower',
#        'grvs_mag', 'rv_amplitude_robust', 'astrometric_params_solved',
#        'phot_rp_n_blended_transits', 'rv_nb_transits', 'matched_transits',
#        'duplicated_source', 'astrometric_excess_noise_sig',
#        'solution_id_gaia_source', 'ecl_lat', 'rv_expected_sig_to_noise',
#        'astrometric_n_bad_obs_al', 'ebpminrp_gspphot_lower',
#        'has_mcmc_gspphot', 'random_index', 'bp_g', 'phot_proc_mode',
#        'vbroad_nb_transits', 'logg_gspphot_upper', 'ra_error_gaia_source',
#        'teff_gspphot', 'azero_gspphot', 'astrometric_primary_flag',
#        'new_matched_transits', 'pmra_pmdec_corr',
#        'astrometric_excess_noise', 'pseudocolour_error',
#        'rv_time_duration', 'logg_gspphot_lower', 'pseudocolour',
#        'pmdec_gaia_source', 'ra_parallax_corr',
#        'rv_nb_deblended_transits', 'designation', 'phot_bp_mean_mag',
#        'logg_gspphot', 'scan_direction_strength_k4',
#        'scan_direction_strength_k3', 'scan_direction_strength_k2',
#        'scan_direction_strength_k1', 'teff_gspphot_upper',
#        'astrometric_n_good_obs_al_gaia_source', 'parallax_over_error',
#        'rv_visibility_periods_used', 'has_mcmc_msc',
#        'nu_eff_used_in_astrometry', 'in_qso_candidates',
#        'pmdec_pseudocolour_corr', 'azero_gspphot_lower',
#        'pmra_gaia_source', 'pmdec_error_gaia_source',
#        'phot_rp_mean_flux_over_error', 'mh_gspphot', 'ag_gspphot',
#        'teff_gspphot_lower', 'ipd_frac_multi_peak', 'mh_gspphot_upper',
#        'ipd_frac_odd_win', 'phot_bp_mean_flux_over_error',
#        'grvs_mag_error', 'phot_g_mean_flux', 'ra_dec_corr',
#        'phot_variable_flag', 'ebpminrp_gspphot', 'phot_bp_mean_flux',
#        'libname_gspphot', 'phot_bp_n_contaminated_transits',
#        'radial_velocity', 'dec_error_gaia_source',
#        'astrometric_sigma5d_max', 'ecl_lon', 'pm', 'phot_g_mean_mag',
#        'absolute_phot_g_mean_mag', 'ra_pseudocolour_corr_gaia_source',
#        'dec_gaia_source', 'phot_bp_n_blended_transits_gaia_source',
#        'non_single_star_gaia_source', 'has_rvs_gaia_source',
#        'has_xp_sampled_gaia_source', 'parallax_error_gaia_source',
#        'grvs_mag_nb_transits_gaia_source',
#        'parallax_pseudocolour_corr_gaia_source',
#        'has_xp_continuous_gaia_source', 'phot_rp_mean_flux_gaia_source',
#        'scan_direction_mean_k4_gaia_source',
#        'scan_direction_mean_k3_gaia_source', 'dec_pmra_corr_gaia_source',
#        'rv_atm_param_origin_gaia_source',
#        'visibility_periods_used_gaia_source',
#        'scan_direction_mean_k2_gaia_source',
#        'radial_velocity_error_gaia_source', 'vbroad_error_gaia_source',
#        'scan_direction_mean_k1_gaia_source', 'g_rp_gaia_source',
#        'rv_template_logg_gaia_source', 'in_andromeda_survey_gaia_source',
#        'ra_gaia_source', 'rv_method_used_gaia_source',
#        'ref_epoch_gaia_source', 'phot_bp_n_obs_gaia_source',
#        'ra_pmdec_corr_gaia_source', 'mh_gspphot_lower_gaia_source',
#        'azero_gspphot_upper_gaia_source',
#        'rv_renormalised_gof_gaia_source', 'vbroad_gaia_source',
#        'phot_rp_n_obs_gaia_source', 'parallax_gaia_source',
#        'ra_pmra_corr_gaia_source', 'matched_transits_removed_gaia_source',
#        'rvs_spec_sig_to_noise_gaia_source',
#        'astrometric_chi2_al_gaia_source',
#        'ipd_gof_harmonic_amplitude_gaia_source',
#        'phot_bp_mean_flux_error_gaia_source',
#        'rv_chisq_pvalue_gaia_source', 'astrometric_n_obs_ac_gaia_source',
#        'dec_pseudocolour_corr_gaia_source',
#        'distance_gspphot_gaia_source', 'bp_rp_gaia_source',
#        'in_galaxy_candidates_gaia_source',
#        'astrometric_matched_transits_gaia_source',
#        'phot_bp_rp_excess_factor_gaia_source',
#        'astrometric_n_obs_al_gaia_source',
#        'classprob_dsc_combmod_galaxy_gaia_source',
#        'pmra_error_gaia_source', 'parallax_pmra_corr_gaia_source',
#        'ipd_gof_harmonic_phase_gaia_source',
#        'ag_gspphot_lower_gaia_source',
#        'distance_gspphot_upper_gaia_source',
#        'parallax_pmdec_corr_gaia_source',
#        'phot_rp_mean_flux_error_gaia_source', 'b_gaia_source',
#        'ruwe_gaia_source', 'has_epoch_photometry_gaia_source',
#        'classprob_dsc_combmod_star_gaia_source',
#        'phot_rp_mean_mag_gaia_source', 'has_epoch_rv_gaia_source',
#        'l_gaia_source', 'dec_pmdec_corr_gaia_source',
#        'dec_parallax_corr_gaia_source', 'phot_g_n_obs_gaia_source',
#        'rv_template_teff_gaia_source',
#        'phot_g_mean_flux_error_gaia_source',
#        'astrometric_gof_al_gaia_source',
#        'classprob_dsc_combmod_quasar_gaia_source',
#        'ebpminrp_gspphot_upper_gaia_source',
#        'phot_rp_n_contaminated_transits_gaia_source',
#        'rv_template_fe_h_gaia_source',
#        'pmra_pseudocolour_corr_gaia_source',
#        'phot_g_mean_flux_over_error_gaia_source',
#        'ag_gspphot_upper_gaia_source', 'source_id_2_gaia_source',
#        'distance_gspphot_lower_gaia_source', 'grvs_mag_gaia_source',
#        'rv_amplitude_robust_gaia_source',
#        'astrometric_params_solved_gaia_source',
#        'phot_rp_n_blended_transits_gaia_source',
#        'rv_nb_transits_gaia_source', 'matched_transits_gaia_source',
#        'duplicated_source_gaia_source',
#        'astrometric_excess_noise_sig_gaia_source',
#        'solution_id_gaia_source', 'ecl_lat_gaia_source',
#        'rv_expected_sig_to_noise_gaia_source',
#        'astrometric_n_bad_obs_al_gaia_source',
#        'ebpminrp_gspphot_lower_gaia_source',
#        'has_mcmc_gspphot_gaia_source', 'random_index_gaia_source',
#        'bp_g_gaia_source', 'phot_proc_mode_gaia_source',
#        'vbroad_nb_transits_gaia_source', 'logg_gspphot_upper_gaia_source',
#        'ra_error_gaia_source', 'teff_gspphot_gaia_source',
#        'azero_gspphot_gaia_source',
#        'astrometric_primary_flag_gaia_source',
#        'new_matched_transits_gaia_source', 'pmra_pmdec_corr_gaia_source',
#        'astrometric_excess_noise_gaia_source',
#        'pseudocolour_error_gaia_source', 'rv_time_duration_gaia_source',
#        'logg_gspphot_lower_gaia_source', 'pseudocolour_gaia_source',
#        'pmdec_gaia_source', 'ra_parallax_corr_gaia_source',
#        'rv_nb_deblended_transits_gaia_source', 'designation_gaia_source',
#        'phot_bp_mean_mag_gaia_source', 'logg_gspphot_gaia_source',
#        'scan_direction_strength_k4_gaia_source',
#        'scan_direction_strength_k3_gaia_source',
#        'scan_direction_strength_k2_gaia_source',
#        'scan_direction_strength_k1_gaia_source',
#        'teff_gspphot_upper_gaia_source',
#        'astrometric_n_good_obs_al_gaia_source',
#        'parallax_over_error_gaia_source',
#        'rv_visibility_periods_used_gaia_source',
#        'has_mcmc_msc_gaia_source',
#        'nu_eff_used_in_astrometry_gaia_source',
#        'in_qso_candidates_gaia_source',
#        'pmdec_pseudocolour_corr_gaia_source',
#        'azero_gspphot_lower_gaia_source', 'pmra_gaia_source',
#        'pmdec_error_gaia_source',
#        'phot_rp_mean_flux_over_error_gaia_source',
#        'mh_gspphot_gaia_source', 'ag_gspphot_gaia_source',
#        'teff_gspphot_lower_gaia_source',
#        'ipd_frac_multi_peak_gaia_source', 'mh_gspphot_upper_gaia_source',
#        'ipd_frac_odd_win_gaia_source',
#        'phot_bp_mean_flux_over_error_gaia_source',
#        'grvs_mag_error_gaia_source', 'phot_g_mean_flux_gaia_source',
#        'ra_dec_corr_gaia_source', 'phot_variable_flag_gaia_source',
#        'ebpminrp_gspphot_gaia_source', 'phot_bp_mean_flux_gaia_source',
#        'libname_gspphot_gaia_source',
#        'phot_bp_n_contaminated_transits_gaia_source',
#        'radial_velocity_gaia_source', 'dec_error_gaia_source',
#        'astrometric_sigma5d_max_gaia_source', 'ecl_lon_gaia_source',
#        'pm_gaia_source', 'phot_g_mean_mag_gaia_source',
#        'ra_pseudocolour_corr_gaia_source', 'dec_gaia_source',
#        'phot_bp_n_blended_transits_gaia_source',
#        'non_single_star_gaia_source', 'has_rvs_gaia_source',
#        'has_xp_sampled_gaia_source', 'parallax_error_gaia_source',
#        'grvs_mag_nb_transits_gaia_source',
#        'parallax_pseudocolour_corr_gaia_source',
#        'has_xp_continuous_gaia_source', 'phot_rp_mean_flux_gaia_source',
#        'scan_direction_mean_k4_gaia_source',
#        'scan_direction_mean_k3_gaia_source', 'dec_pmra_corr_gaia_source',
#        'rv_atm_param_origin_gaia_source',
#        'visibility_periods_used_gaia_source',
#        'scan_direction_mean_k2_gaia_source',
#        'radial_velocity_error_gaia_source', 'vbroad_error_gaia_source',
#        'scan_direction_mean_k1_gaia_source', 'g_rp_gaia_source',
#        'rv_template_logg_gaia_source', 'in_andromeda_survey_gaia_source',
#        'ra_gaia_source', 'rv_method_used_gaia_source',
#        'ref_epoch_gaia_source', 'phot_bp_n_obs_gaia_source',
#        'ra_pmdec_corr_gaia_source', 'mh_gspphot_lower_gaia_source',
#        'azero_gspphot_upper_gaia_source',
#        'rv_renormalised_gof_gaia_source', 'vbroad_gaia_source',
#        'phot_rp_n_obs_gaia_source', 'parallax_gaia_source',
#        'ra_pmra_corr_gaia_source', 'matched_transits_removed_gaia_source',
#        'rvs_spec_sig_to_noise_gaia_source',
#        'astrometric_chi2_al_gaia_source',
#        'ipd_gof_harmonic_amplitude_gaia_source',
#        'phot_bp_mean_flux_error_gaia_source',
#        'rv_chisq_pvalue_gaia_source', 'astrometric_n_obs_ac_gaia_source',
#        'dec_pseudocolour_corr_gaia_source',
#        'distance_gspphot_gaia_source', 'bp_rp_gaia_source',
#        'in_galaxy_candidates_gaia_source',
#        'astrometric_matched_transits_gaia_source',
#        'phot_bp_rp_excess_factor_gaia_source',
#        'astrometric_n_obs_al_gaia_source',
#        'classprob_dsc_combmod_galaxy_gaia_source',
#        'pmra_error_gaia_source', 'parallax_pmra_corr_gaia_source',
#        'ipd_gof_harmonic_phase_gaia_source',
#        'ag_gspphot_lower_gaia_source',
#        'distance_gspphot_upper_gaia_source',
#        'parallax_pmdec_corr_gaia_source',
#        'phot_rp_mean_flux_error_gaia_source', 'b_gaia_source',
#        'ruwe_gaia_source', 'has_epoch_photometry_gaia_source',
#        'classprob_dsc_combmod_star_gaia_source',
#        'phot_rp_mean_mag_gaia_source', 'has_epoch_rv_gaia_source',
#        'l_gaia_source', 'dec_pmdec_corr_gaia_source',
#        'dec_parallax_corr_gaia_source', 'phot_g_n_obs_gaia_source',
#        'rv_template_teff_gaia_source',
#        'phot_g_mean_flux_error_gaia_source',
#        'astrometric_gof_al_gaia_source',
#        'classprob_dsc_combmod_quasar_gaia_source',
#        'ebpminrp_gspphot_upper_gaia_source',
#        'phot_rp_n_contaminated_transits_gaia_source',
#        'rv_template_fe_h_gaia_source',
#        'pmra_pseudocolour_corr_gaia_source',
#        'phot_g_mean_flux_over_error_gaia_source',
#        'ag_gspphot_upper_gaia_source', 'source_id_2_gaia_source',
#        'distance_gspphot_lower_gaia_source', 'grvs_mag_gaia_source',
#        'rv_amplitude_robust_gaia_source',
#        'astrometric_params_solved_gaia_source',
#        'phot_rp_n_blended_transits_gaia_source',
#        'rv_nb_transits_gaia_source', 'matched_transits_gaia_source',
#        'duplicated_source_gaia_source',
#        'astrometric_excess_noise_sig_gaia_source',
#        'solution_id_gaia_source', 'ecl_lat_gaia_source',
#        'rv_expected_sig_to_noise_gaia_source',
#        'astrometric_n_bad_obs_al_gaia_source',
#        'ebpminrp_gspphot_lower_gaia_source',
#        'has_mcmc_gspphot_gaia_source', 'random_index_gaia_source',
#        'bp_g_gaia_source', 'phot_proc_mode_gaia_source',
#        'vbroad_nb_transits_gaia_source', 'logg_gspphot_upper_gaia_source',
#        'ra_error_gaia_source', 'teff_gspphot_gaia_source',
#        'azero_gspphot_gaia_source',
#        'astrometric_primary_flag_gaia_source',
#        'new_matched_transits_gaia_source', 'pmra_pmdec_corr_gaia_source',
#        'astrometric_excess_noise_gaia_source',
#        'pseudocolour_error_gaia_source', 'rv_time_duration_gaia_source',
#        'logg_gspphot_lower_gaia_source', 'pseudocolour_gaia_source',
#        'pmdec_gaia_source', 'ra_parallax_corr_gaia_source',
#        'rv_nb_deblended_transits_gaia_source', 'designation_gaia_source',
#        'phot_bp_mean_mag_gaia_source', 'logg_gspphot_gaia_source',
#        'scan_direction_strength_k4_gaia_source',
#        'scan_direction_strength_k3_gaia_source',
#        'scan_direction_strength_k2_gaia_source',
#        'scan_direction_strength_k1_gaia_source',
#        'teff_gspphot_upper_gaia_source',
#        'astrometric_n_good_obs_al_gaia_source',
#        'parallax_over_error_gaia_source',
#        'rv_visibility_periods_used_gaia_source',
#        'has_mcmc_msc_gaia_source',
#        'nu_eff_used_in_astrometry_gaia_source',
#        'in_qso_candidates_gaia_source',
#        'pmdec_pseudocolour_corr_gaia_source',
#        'azero_gspphot_lower_gaia_source', 'pmra_gaia_source',
#        'pmdec_error_gaia_source',
#        'phot_rp_mean_flux_over_error_gaia_source',
#        'mh_gspphot_gaia_source', 'ag_gspphot_gaia_source',
#        'teff_gspphot_lower_gaia_source',
#        'ipd_frac_multi_peak_gaia_source', 'mh_gspphot_upper_gaia_source',
#        'ipd_frac_odd_win_gaia_source',
#        'phot_bp_mean_flux_over_error_gaia_source',
#        'grvs_mag_error_gaia_source', 'phot_g_mean_flux_gaia_source',
#        'ra_dec_corr_gaia_source', 'phot_variable_flag_gaia_source',
#        'ebpminrp_gspphot_gaia_source', 'phot_bp_mean_flux_gaia_source',
#        'libname_gspphot_gaia_source',
#        'phot_bp_n_contaminated_transits_gaia_source',
#        'radial_velocity_gaia_source', 'dec_error_gaia_source',
#        'astrometric_sigma5d_max_gaia_source', 'ecl_lon_gaia_source',
#        'pm_gaia_source', 'phot_g_mean_mag_gaia_source'], dtype=object)

# %% [markdown]
# ## Generate figure

# %%
# dr3['period_year']

# %%
include_koi = True
include_individuals = True
include_orbits = True
include_solar_system = True

# make the KOI symbol visible in the legend
eod_df_koi['DIST'].replace(0, np.nan, inplace=True)
eod_df_koi.sort_values('DIST', inplace=True, ascending=True)

def annotate_df(row):  
    #     https://stackoverflow.com/questions/15910019/annotate-data-points-while-plotting-from-pandas-dataframe
    ax.annotate(row.planet_name, (row.period_year, row.a_phot_muas),
                xytext=(10,-5), 
                textcoords='offset points',
                size=18, 
                color='darkslategrey')
    

include_dr3 = True
# include_dr3 = False
    
x = 'period_year' 
y = 'a_phot_muas'

if y == 'a_phot_muas':
    factor = 1000

colour_by = 'distance_pc'
norm = mp.colors.LogNorm()
# norm = None
colormap='viridis'
colormap='cubehelix'

fig, ax = pl.subplots()
df.plot(x, y, kind='scatter', logx=True, logy=True, c=parameter_mapping_all['nasa'][colour_by], norm=norm, colormap=colormap, s=30, alpha=0.9, ax=ax, zorder=1, label='Known exoplanets')
if include_koi:
    eod_df_koi.plot(x, y, kind='scatter', logx=True, logy=True, c=parameter_mapping_all['eod'][colour_by], colormap=colormap, s=25, marker='s', alpha=0.9, zorder=-50, norm=norm, ax=ax, colorbar=False, label='Kepler Objects of Interest')
pl.ylim((1e-8*factor, 40*factor))
pl.xlim((1e-3, 300))
if include_orbits:
    selected_systems.plot(x, y, kind='scatter', logx=True, logy=True, s=300, c=parameter_mapping_all['nasa'][colour_by], ax=ax, norm=norm, colormap=colormap, colorbar=False, label='Measured orbits',  marker='*', edgecolor='k') #,    
if include_dr3:
    # dr3.plot(x, y, kind='scatter', logx=True, logy=True, s=100, c='distance_pc', ax=ax, norm=norm, colormap=colormap, colorbar=False, label='Gaia DR3 subst. cand.',  marker='*', edgecolor='k') #,    
    dr3.plot(x, y, kind='scatter', logx=True, logy=True, s=100, c='distance_pc', ax=ax, norm=norm, colormap=colormap, colorbar=False, label='Gaia DR3 subst. cand.',  marker='*', edgecolor='k') #,    
if include_individuals:
    individuals.plot(x, y, kind='scatter', logx=True, logy=True, s=200, c=colour_by, ax=ax, norm=norm, colormap=colormap, colorbar=False, label='Hipparcos-Gaia systems',  marker='D', edgecolor='k', alpha=0.7) #,
if include_solar_system:
    solar_system.plot(x, y, kind='scatter', logx=True, logy=True, s=200, c=colour_by, ax=ax, norm=norm, colormap=colormap, colorbar=False, marker='^', label='Solar system at 10pc', edgecolor='k')
    _ = solar_system.apply(annotate_df, axis=1)
pl.xlabel('Orbital period (year)')
pl.ylabel('Minimum semimajor axis (micro-arcsec)')
ax.grid(ls='--', color='0.8')
ax.set_zorder(-52)

xticks = [0.001, 0.01, 0.1, 1, 10, 100] 
xtick_labels = np.array(['0.001', '0.01', '0.1', '1', '10', '100'])
pl.xticks(xticks, xtick_labels)

yticks = [1e-4, 1e-3, 1e-2, 1e-1, 1, 10, 100, 1000, 1e4] 
ytick_labels = np.array(yticks).astype(str)
ytick_labels = np.array(['0.0001', '0.001', '0.01', '0.1', '1', '10', '100', '1000', '10000'])
pl.yticks(yticks, ytick_labels)

cax = fig.get_axes()[1]
cax.set_ylabel('Distance from Sun (pc)')
# pl.legend(loc=4, framealpha=0.5)
# pl.legend(None)
ax.legend().set_visible(False)

pl.text(0.68, 0.03, 'NasaExoplanetArchive & ExoplanetOrbitDatabase', horizontalalignment='left', verticalalignment='top',
        transform=pl.gca().transAxes, fontsize=10)

pl.title('Astrometric signatures of exoplanets')
if save_plot:
    figure_file_name = os.path.join(TEMPORARY_DIR, '{}_{}_{}_astrometry_signatures.png'.format(selected_table_name, include_individuals, include_orbits))
    pl.savefig(figure_file_name, transparent=False, bbox_inches='tight', pad_inches=0.05)        
display(figure_file_name)
# Out:
# /tmp/ipykernel_444/950434543.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eod_df_koi['DIST'].replace(0, np.nan, inplace=True)
# /tmp/ipykernel_444/950434543.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eod_df_koi.sort_values('DIST', inplace=True, ascending=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 35>()
#      32 colormap='cubehelix'
#      34 fig, ax = pl.subplots()
# ---> 35 df.plot(x, y, kind='scatter', logx=True, logy=True, c=parameter_mapping_all['nasa'][colour_by], norm=norm, colormap=colormap, s=30, alpha=0.9, ax=ax, zorder=1, label='Known exoplanets')
#      36 if include_koi:
#      37     eod_df_koi.plot(x, y, kind='scatter', logx=True, logy=True, c=parameter_mapping_all['eod'][colour_by], colormap=colormap, s=25, marker='s', alpha=0.9, zorder=-50, norm=norm, ax=ax, colorbar=False, label='Kepler Objects of Interest')
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_core.py:917, in PlotAccessor.__call__(self, *args, **kwargs)
#     915 if kind in self._dataframe_kinds:
#     916     if isinstance(data, ABCDataFrame):
# --> 917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918     else:
#     919         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1114, in ScatterPlot._make_plot(self)
#    1112 else:
#    1113     label = None
# -> 1114 scatter = ax.scatter(
#    1115     data[x].values,
#    1116     data[y].values,
#    1117     c=c_values,
#    1118     label=label,
#    1119     cmap=cmap,
#    1120     norm=norm,
#    1121     **self.kwds,
#    1122 )
#    1123 if cb:
#    1124     cbar_label = c if c_is_column else ""
#
# TypeError: scatter() got multiple values for keyword argument 'norm'

# %%
norm = mp.colors.LogNorm()

pl.figure()
ax = pl.gca()
dr3.plot(x, y, kind='scatter', logx=True, logy=True, s=50, c='distance_pc', ax=ax, norm=norm, colormap=colormap, colorbar=True, label='Gaia DR3 subst. cand.',  marker='o', edgecolor='k', alpha=1) #,    
pl.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 5>()
#       3 pl.figure()
#       4 ax = pl.gca()
# ----> 5 dr3.plot(x, y, kind='scatter', logx=True, logy=True, s=50, c='distance_pc', ax=ax, norm=norm, colormap=colormap, colorbar=True, label='Gaia DR3 subst. cand.',  marker='o', edgecolor='k', alpha=1) #,
#       6 pl.show()
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_core.py:917, in PlotAccessor.__call__(self, *args, **kwargs)
#     915 if kind in self._dataframe_kinds:
#     916     if isinstance(data, ABCDataFrame):
# --> 917         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918     else:
#     919         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File /opt/conda/envs/astrom/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1114, in ScatterPlot._make_plot(self)
#    1112 else:
#    1113     label = None
# -> 1114 scatter = ax.scatter(
#    1115     data[x].values,
#    1116     data[y].values,
#    1117     c=c_values,
#    1118     label=label,
#    1119     cmap=cmap,
#    1120     norm=norm,
#    1121     **self.kwds,
#    1122 )
#    1123 if cb:
#    1124     cbar_label = c if c_is_column else ""
#
# TypeError: scatter() got multiple values for keyword argument 'norm'

# %%
len(dr3)
# Out:
# 1778

# %%
# analysis_dataset_name = 'nss_source_all'
gaia_data_release = 'gaiadr3'
source_id_array = dr3['source_id']

gaia_table_name = 'gaia_source'

nss_source_all = get_gaiadr_data('dr3a', data_dir, source_id_array, gaia_data_release, gaia_table_name=gaia_table_name, overwrite_query=False)

dr3 = dr3.merge(nss_source_all.drop_duplicates(subset='source_id', keep="first"), left_on='source_id', right_on='source_id', suffixes=('', '_gaia_source'))
colour_by = 'bp_rp'
norm = mp.colors.LogNorm()
colormap='rainbow'


# display(nss_source_all[['source_id']].agg(['count', 'size', 'nunique']))
# dr3.nss.add_absolute_magnitude()
dr3.nss.plot_cmd(c=colour_by, colormap=colormap)
# Out:
# universal_helpers not available
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:33: UserWarning: registration of accessor <class 'pystrometry.utils.du437_tools.NssDataFrame'> under name 'nss' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class NssDataFrame:
# /Users/jsahlmann/code/github/JohannesSahlmann/pystrometry/pystrometry/utils/du437_tools.py:561: UserWarning: registration of accessor <class 'pystrometry.utils.du437_tools.NssMonteCarloDataFrame'> under name 'nssmc' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class NssMonteCarloDataFrame(NssDataFrame):
# Retrieved 1778 rows from gaiadr3.gaia_source

# %%
selected = dr3.copy()
# selected = selected.query('parallax < 10')
selected = selected.nss.add_absolute_magnitude()
selected = selected.nss.add_colour()
colour_by = 'bp_rp'
# colour_by = 'parallax'
norm = mp.colors.LogNorm()
colormap='rainbow'
fig = pl.figure()
ax = pl.gca()
selected.plot('bp_rp', 'absolute_phot_g_mean_mag', kind='scatter', c=colour_by, colormap=colormap, ax=ax)
# y_col = 'bp_rp'
# y_col = 'p1_a1_mas'
# x_col = 'period'
# selected.plot(x_col, y_col, kind='scatter', c=colour_by, colormap=colormap, ax=ax)
pl.title(f'{len(selected)}')
ax.set_yscale('symlog')
# ax.invert_yaxis()
pl.show()

# %%
np.array(dr3.columns)
